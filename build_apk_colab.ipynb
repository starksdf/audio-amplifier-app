# %% [markdown]
# # 🔊 Audio Booster - APK Builder
# Run each cell in order. The final cell will produce a downloadable APK.

# %%
# Cell 1: Install dependencies
# !sudo apt-get update -qq
# !sudo apt-get install -y -qq openjdk-17-jdk zip unzip autoconf libtool pkg-config zlib1g-dev libncurses5-dev libncursesw5-dev libtinfo5 cmake libffi-dev libssl-dev
# !pip install -q buildozer cython

# %%
# Cell 2: Clone the repo
# !git clone https://github.com/starksdf/audio-amplifier-app.git
# %cd audio-amplifier-app

# %%
# Cell 3: Build APK (this takes 30-60 minutes)
import os
os.environ['BUILDOZER_WARN_ON_ROOT'] = '0'
# !buildozer android debug 2>&1 | tail -50

# %%
# Cell 4: Download APK
import glob
apks = glob.glob('bin/*.apk')
if apks:
    print(f'APK found: {apks[0]}')
    from google.colab import files
    files.download(apks[0])
else:
    print('No APK found. Check the build output above for errors.')
    # !ls -la bin/ 2>/dev/null || echo 'bin/ not found'
